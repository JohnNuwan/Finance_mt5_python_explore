# %% [markdown]
# # Downloads Datas From MT5

# %%
import pandas as pd
import numpy as np
import mplfinance as mpf
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt
from binance.client import Client
from statistics import mean
import os
import sys 

from rich import print
from rich.console import Console
from rich.style import Style
import pandas as pd 
import numpy as np
from datetime import datetime 
import requests
import json

import time

import schedule

# plt.rcParams['figure.figsize'] = [12, 7]
# plt.rc('font', size=14)

# %%
host = "localhost"
port = 8090
debug = True

url = f"http://{host}:{port}"
os.system('cls')
cs = Console()
cs.log("Client")
cs.log(host,port)
# Out:
# [10:55:32] Client                                        ]8;id=185502;file://C:\Users\Azazel\AppData\Local\Temp\ipykernel_18276\2841750992.py\Temp/ipykernel_18276/2841750992.py]8;;\:]8;id=784913;file://C:\Users\Azazel\AppData\Local\Temp\ipykernel_18276\2841750992.py#8\8]8;;\
#            localhost 8090                                ]8;id=61878;file://C:\Users\Azazel\AppData\Local\Temp\ipykernel_18276\2841750992.py\Temp/ipykernel_18276/2841750992.py]8;;\:]8;id=487711;file://C:\Users\Azazel\AppData\Local\Temp\ipykernel_18276\2841750992.py#9\9]8;;\

# %%
cs.log("Try to get Connection : "+url)
r = requests.get(url)
cs.log(r.text)
name = "GOLD"#input('Enter Symbol Name :')
timeframe = "M1"
num_bars= 2000
signal = 0
count = 0
triger_signal_init = 0
lot = 0.02	
comment = f'Ichimoku_{timeframe}'
# Out:
# [10:55:33] Try to get Connection : http://localhost:8090 ]8;id=251074;file://C:\Users\Azazel\AppData\Local\Temp\ipykernel_18276\2535925695.py\Temp/ipykernel_18276/2535925695.py]8;;\:]8;id=495495;file://C:\Users\Azazel\AppData\Local\Temp\ipykernel_18276\2535925695.py#1\1]8;;\
#            {"status":1,"message":"ok","Serveur":"Serveur ]8;id=824360;file://C:\Users\Azazel\AppData\Local\Temp\ipykernel_18276\2535925695.py\Temp/ipykernel_18276/2535925695.py]8;;\:]8;id=221911;file://C:\Users\Azazel\AppData\Local\Temp\ipykernel_18276\2535925695.py#3\3]8;;\
#            Finance"}

# %%
route_data = f"{url}/OHLC/{name}/{timeframe}/{num_bars}"
r2 = requests.get(route_data)
data = json.loads(r2.text)
df = pd.read_json(data)
df
# Out:
#                         open     high      low    close  tick_volume  spread  \
# 2022-03-21 01:35:00  1918.59  1918.64  1918.41  1918.54           19     350
# 2022-03-21 01:36:00  1918.54  1918.80  1918.41  1918.42           18     330
# 2022-03-21 01:37:00  1918.45  1918.87  1918.43  1918.79           31     410
# 2022-03-21 01:38:00  1918.82  1919.10  1918.79  1919.10           22     340
# 2022-03-21 01:39:00  1919.10  1919.10  1918.86  1918.98           26     380
# ...                      ...      ...      ...      ...          ...     ...
# 2022-03-22 11:51:00  1925.40  1925.90  1925.13  1925.56           61     276
# 2022-03-22 11:52:00  1925.56  1925.56  1925.16  1925.22           51     280
# 2022-03-22 11:53:00  1925.22  1925.22  1924.67  1925.13           48     270
# 2022-03-22 11:54:00  1925.11  1925.11  1924.83  1924.88           20     270
# 2022-03-22 11:55:00  1924.88  1925.14  1924.88  1924.99           26     256
#
#                      real_volume
# 2022-03-21 01:35:00            0
# 2022-03-21 01:36:00            0
# 2022-03-21 01:37:00            0
# 2022-03-21 01:38:00            0
# 2022-03-21 01:39:00            0
# ...                          ...
# 2022-03-22 11:51:00            0
# 2022-03-22 11:52:00            0
# 2022-03-22 11:53:00            0
# 2022-03-22 11:54:00            0
# 2022-03-22 11:55:00            0
#
# [2000 rows x 7 columns]

# %%
mask_chikou = df.copy()
mask_chikou['chikou'] = mask_chikou.close.shift(-26).dropna()
mask_chikou.dropna(inplace=True)

# %%
mask_chikou
# Out:
#                         open     high      low    close  tick_volume  spread  \
# 2022-03-21 01:35:00  1918.59  1918.64  1918.41  1918.54           19     350
# 2022-03-21 01:36:00  1918.54  1918.80  1918.41  1918.42           18     330
# 2022-03-21 01:37:00  1918.45  1918.87  1918.43  1918.79           31     410
# 2022-03-21 01:38:00  1918.82  1919.10  1918.79  1919.10           22     340
# 2022-03-21 01:39:00  1919.10  1919.10  1918.86  1918.98           26     380
# ...                      ...      ...      ...      ...          ...     ...
# 2022-03-22 11:25:00  1924.65  1925.15  1924.44  1924.94           63     270
# 2022-03-22 11:26:00  1924.93  1924.93  1924.54  1924.66           49     240
# 2022-03-22 11:27:00  1924.66  1924.66  1923.63  1923.83           74     210
# 2022-03-22 11:28:00  1923.81  1923.84  1923.30  1923.80           80     230
# 2022-03-22 11:29:00  1923.80  1924.75  1923.80  1924.32           83     150
#
#                      real_volume   chikou
# 2022-03-21 01:35:00            0  1919.30
# 2022-03-21 01:36:00            0  1919.60
# 2022-03-21 01:37:00            0  1919.34
# 2022-03-21 01:38:00            0  1919.83
# 2022-03-21 01:39:00            0  1919.85
# ...                          ...      ...
# 2022-03-22 11:25:00            0  1925.56
# 2022-03-22 11:26:00            0  1925.22
# 2022-03-22 11:27:00            0  1925.13
# 2022-03-22 11:28:00            0  1924.88
# 2022-03-22 11:29:00            0  1924.99
#
# [1974 rows x 8 columns]

# %%
nine_periodf_high = df['high'].rolling(window= 9).max()
nine_periodf_low = df['low'].rolling(window= 9).min()

periodf26_high = df['high'].rolling(window=26).max()
periodf26_low = df['low'].rolling(window=26).min()


df['tenkan_sen'] = (nine_periodf_high + nine_periodf_low) /2

# Kijun-sen (Base Line): (26-periodf high + 26-periodf low)/2))
df['kijun_sen'] = (periodf26_high + periodf26_low) / 2
df['prev_kijun_sen'] = df['kijun_sen'].shift(1)
df['prev_tenkan_sen'] = df['tenkan_sen'].shift(1)

# %%
# Senkou Span A (Leadfing Span A): (Conversion Line + Base Line)/2))
df['senkou_span_a'] = ((df['tenkan_sen'] + df['kijun_sen']) / 2).shift(26)
# Senkou Span B (Leadfing Span B): (52-periodf high + 52-periodf low)/2))
periodf52_high = df['high'].rolling(window=52).max()
periodf52_low = df['low'].rolling(window=52).min()
df['senkou_span_b'] = ((periodf52_high + periodf52_low) / 2).shift(52)

# %%
df.tail(4)
# Out:
#                         open     high      low    close  tick_volume  spread  \
# 2022-03-22 11:52:00  1925.56  1925.56  1925.16  1925.22           51     280
# 2022-03-22 11:53:00  1925.22  1925.22  1924.67  1925.13           48     270
# 2022-03-22 11:54:00  1925.11  1925.11  1924.83  1924.88           20     270
# 2022-03-22 11:55:00  1924.88  1925.14  1924.88  1924.99           26     256
#
#                      real_volume  tenkan_sen  kijun_sen  prev_kijun_sen  \
# 2022-03-22 11:52:00            0    1925.020    1924.60         1924.60
# 2022-03-22 11:53:00            0    1925.245    1924.60         1924.60
# 2022-03-22 11:54:00            0    1925.285    1924.85         1924.60
# 2022-03-22 11:55:00            0    1925.285    1924.85         1924.85
#
#                      prev_tenkan_sen  senkou_span_a  senkou_span_b
# 2022-03-22 11:52:00         1925.020      1924.3275       1926.787
# 2022-03-22 11:53:00         1925.020      1924.2450       1926.382
# 2022-03-22 11:54:00         1925.245      1924.1650       1926.312
# 2022-03-22 11:55:00         1925.285      1924.1650       1926.312

# %%
plt.figure(figsize=(12,8)).close.plot()
df.tenkan_sen.plot()
df.kijun_sen.plot()
df.senkou_span_a.plot()
df.senkou_span_b.plot()
# Out:
# <AxesSubplot:>
